# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
df  = pd.read_csv("Caschool.csv")
df.head()
# Out:
#    Unnamed: 0  distcod   county                         district grspan  ...        str     avginc      elpct     readscr     mathscr
# 0           1    75119  Alameda               Sunol Glen Unified  KK-08  ...  17.889910  22.690001   0.000000  691.599976  690.000000
# 1           2    61499    Butte             Manzanita Elementary  KK-08  ...  21.524664   9.824000   4.583333  660.500000  661.900024
# 2           3    61549    Butte      Thermalito Union Elementary  KK-08  ...  18.697226   8.978000  30.000002  636.299988  650.900024
# 3           4    61457    Butte  Golden Feather Union Elementary  KK-08  ...  17.357143   8.978000   0.000000  651.900024  643.500000
# 4           5    61523    Butte         Palermo Union Elementary  KK-08  ...  18.671329   9.080333  13.857677  641.799988  639.900024
#
# [5 rows x 18 columns]

# %%
print("Sample Size:", len(df))
print(" ")

print("Test Score Mean:", df["testscr"].mean())
print("Test Score Median:", df["testscr"].median())
print("Test Score Std Dev:", df["testscr"].std())

print(" ")

print("Student Teacher Ratio Mean:", df["str"].mean())
print("Student Teacher Ratio Median:", df["str"].median())
print("Student Teacher Ratio Std Dev:", df["str"].std())

print(" ")

print("ELPCT:", df["elpct"].mean())
print("ELPCT:", df["elpct"].median())
print("ELPCT:", df["elpct"].std())
# Out:
# Sample Size: 420
#
# Test Score Mean: 654.156548055013
# Test Score Median: 654.4499816894536
# Test Score Std Dev: 19.053347643618793
#
# Student Teacher Ratio Mean: 19.64042526199704
# Student Teacher Ratio Median: 19.7232084274292
# Student Teacher Ratio Std Dev: 1.891811787233676
#
# ELPCT: 15.768155158630439
# ELPCT: 8.777633666992191
# ELPCT: 18.28592746747183

# %%
# add constant
df = sm.add_constant(df) # df["const"] = 1 

# Run regression model!
reg = sm.OLS(endog=df["testscr"], exog=df[["const", "str"]], missing="drop")
result = reg.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                testscr   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     22.58
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):           2.78e-06
# Time:                        18:05:14   Log-Likelihood:                -1822.2
# No. Observations:                 420   AIC:                             3648.
# Df Residuals:                     418   BIC:                             3657.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        698.9330      9.467     73.825      0.000     680.323     717.543
# ...

# %%
reg = sm.OLS(endog=df["testscr"], exog=df[["const", "str", "elpct"]], missing="drop")

result = reg.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                testscr   R-squared:                       0.426
# Model:                            OLS   Adj. R-squared:                  0.424
# Method:                 Least Squares   F-statistic:                     155.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):           4.62e-51
# Time:                        18:05:18   Log-Likelihood:                -1716.6
# No. Observations:                 420   AIC:                             3439.
# Df Residuals:                     417   BIC:                             3451.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        686.0322      7.411     92.566      0.000     671.464     700.600
# ...

# %%
# str coef ilk hesabımda  ----->   -2.2798   
# str coef ilk hesabımda  ----->   -1.1013  
# Demek ki daha önce modelimde bir Omitted Variable Bias vardı
# İlgili değişkenleri modele eklediğim zaman R2 değerim iyileşti. Str düşündüğüm kadar yüksek bir değer değilmiş!
